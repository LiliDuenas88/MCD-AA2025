# %% [markdown]
# <a href="https://colab.research.google.com/github/LiliDuenas88/MCD-AA2025/blob/master/Tarea_8_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✅**1. Revisión en la literatura de métricas de desempeño**
#
# En problemas de predicción numérica (como tu caso, donde se predice stock), la literatura sugiere varias métricas comunes para evaluar la calidad de un modelo supervisado. Las más relevantes son:
#
# 📌 MAE – Mean Absolute Error (Error Absoluto Medio)
#
# Mide el error promedio entre las predicciones y los valores reales.
#
# MAE=n1​∑∣yi​−y^​i​∣
#
# *  Fácil de interpretar
# *  Penaliza todos los errores por igual
# *  Se usa en inventarios y pronósticos de demanda (Hyndman, 2018)
#
# 📌 RMSE – Root Mean Squared Error (Raíz del Error Cuadrático Medio)
#
# RMSE=n1​∑(yi​−y^​i​)2
#
# *  Penaliza más los errores grandes
# *  Muy usada en modelos de predicción de ventas y forecasting
#
# 📌 R² – Coeficiente de Determinación
#
# R2=1−​SSres​
#      SStot
#
# *  Mide qué porcentaje de la variación de la variable dependiente (stock) es    explicada por el modelo
# *  Muy común en regresión y modelos supervisados

# %% [markdown]
# ✅ **2. Elección de una métrica:**
#
# ⭐ RMSE (Root Mean Squared Error)
#
# Justificación:
#
# Penaliza con mayor fuerza los errores grandes → muy importante en inventarios
#
# Es la métrica más usada en pronósticos de stock, ventas y demanda
#
# Permite comparar modelos en unidades reales (stock)
#
# Datos ya calculados:
#
# MAE = 0.7525
#
# RMSE = 3.0159
#
# R² = 0.9995

# %%
# ================================================================
#   DISEÑO DE EXPERIMENTOS (DOE 2^3) PARA PREDICCIÓN DE STOCK
# ================================================================

import pandas as pd

# -------------------------------------------------------
# 1. Definir factores y niveles para el diseño factorial 2^3
# -------------------------------------------------------

# Niveles bajos (-1) y altos (+1) basados en la distribución real de tus datos
nivel_bajo_precio = df["precio_unitario"].quantile(0.10)   # ejemplo: percentil 10
nivel_alto_precio = df["precio_unitario"].quantile(0.90)   # percentil 90

nivel_bajo_cantidad = df["cantidad_compra"].quantile(0.10)
nivel_alto_cantidad = df["cantidad_compra"].quantile(0.90)

nivel_bajo_venta = df["venta_total"].quantile(0.10)
nivel_alto_venta = df["venta_total"].quantile(0.90)

# -------------------------------------------------------
# 2. Crear las combinaciones del diseño factorial 2^3
# -------------------------------------------------------

DOE = pd.DataFrame({
    "precio_unitario": [nivel_bajo_precio, nivel_alto_precio, nivel_bajo_precio, nivel_alto_precio,
                        nivel_bajo_precio, nivel_alto_precio, nivel_bajo_precio, nivel_alto_precio],

    "cantidad_compra": [nivel_bajo_cantidad, nivel_bajo_cantidad, nivel_alto_cantidad, nivel_alto_cantidad,
                        nivel_bajo_cantidad, nivel_bajo_cantidad, nivel_alto_cantidad, nivel_alto_cantidad],

    "venta_total":     [nivel_bajo_venta, nivel_bajo_venta, nivel_bajo_venta, nivel_bajo_venta,
                        nivel_alto_venta, nivel_alto_venta, nivel_alto_venta, nivel_alto_venta]
})

# Etiquetas de tratamiento (T1 a T8)
DOE.index = [f"T{i}" for i in range(1, 9)]

print("=== DISEÑO DE EXPERIMENTOS 2^3 ===")
display(DOE)

# -------------------------------------------------------
# 3. Predicción del stock usando tu modelo Random Forest
# -------------------------------------------------------

predicciones = modelo.predict(DOE)
DOE["stock_predicho"] = predicciones

print("\n=== RESULTADOS DEL DISEÑO DE EXPERIMENTOS ===")
display(DOE)

# -------------------------------------------------------
# 4. Interpretación automática de los efectos (opcional)
# -------------------------------------------------------

print("\n=== INTERPRETACIÓN RÁPIDA DEL DOE ===")

print("• Si los tratamientos con PRECIO alto generan mayor stock → el precio influye positivamente.")
print("• Si los tratamientos con VENTA total alta generan mayor stock → existe dependencia con ventas.")
print("• Si CANTIDAD alta aumenta stock predicho → efecto directo en inventario.")
print("• Puedes comparar T8 vs T1 para ver el efecto combinado máximo.\n")
# Out:
# === DISEÑO DE EXPERIMENTOS 2^3 ===
#     precio_unitario  cantidad_compra  venta_total
# T1             10.0              1.0         21.2
# T2            200.0              1.0         21.2
# T3             10.0              5.0         21.2
# T4            200.0              5.0         21.2
# T5             10.0              1.0        600.0
# T6            200.0              1.0        600.0
# T7             10.0              5.0        600.0
# T8            200.0              5.0        600.0
# === RESULTADOS DEL DISEÑO DE EXPERIMENTOS ===
#     precio_unitario  cantidad_compra  venta_total  stock_predicho
# T1             10.0              1.0         21.2           159.0
# T2            200.0              1.0         21.2           170.0
# T3             10.0              5.0         21.2           159.0
# T4            200.0              5.0         21.2           170.0
# T5             10.0              1.0        600.0           159.0
# ...
